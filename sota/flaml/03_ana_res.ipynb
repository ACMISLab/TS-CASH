# %%
from pyutils.kvdb.kvdb_json import KVDBJson

import pandas as pd

db = KVDBJson("flaml.json")
df = db.to_dataframe()
df
# Out:
# KVDB File: /Volumes/18212722133/experiments/ts_cash_ms/sota/flaml/flaml.json
#                             k  \
# 0  d1_0_42_precision_weighted
# 1         d1_0_42_f1_weighted
# 2  d2_0_42_precision_weighted
# 3         d2_0_42_f1_weighted
# 4     d1_0_42_recall_weighted
# 5     d2_0_42_recall_weighted
#
#                                          best_config  best_loss dataset_name  \
# 0  {'penalty': 'l2', 'alpha': 1.081744672978736e-...   0.140254           d1
# 1  {'n_estimators': 4, 'num_leaves': 5, 'min_chil...   0.204078           d1
# 2                                     {'C': 0.03125}   0.077558           d2
# 3  {'n_estimators': 4, 'num_leaves': 10, 'min_chi...   0.121324           d2
# 4  {'n_estimators': 4, 'num_leaves': 5, 'min_chil...   0.374503           d1
# 5                         {'C': 0.03701031061542462}   0.277330           d2
#
#           eval_metric  fold_index model  seed  training_time     value
# 0  precision_weighted         0.0   sgd  42.0     155.997343  0.185421
# 1         f1_weighted         0.0  lgbm  42.0     522.979101  0.259220
# 2  precision_weighted         0.0  lrl1  42.0     748.267418  0.291203
# 3         f1_weighted         0.0  lgbm  42.0     680.761925  0.329524
# 4     recall_weighted         0.0  lgbm  42.0     209.273740  0.430605
# 5     recall_weighted         0.0  lrl1  42.0     770.930704  0.538851

# %%
res = df.groupby(by=['dataset_name', 'eval_metric'])['value'].agg(['mean', 'std']).round(3)
res.to_csv("final_res.csv")
