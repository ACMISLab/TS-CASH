# %%
# 对比TS-CASH和 Auto-CASH、AutoMHS-GPT的结果

# %%
from pathlib import Path

import pandas as pd

METRIC_HOME = Path("/Users/sunwu/SW-Research/AutoML-Benchmark/sota/results")
metrics_files = ["auto_cash_vs_tshpo.csv",
                 "automhs_gpt_gpt-4-turbo_vs_tshpo.csv",
                 "automhs_gpt_gpt-4o-mini_vs_tshpo.csv",
                 "automhs_gpt_gpt-4o_vs_tshpo.csv"]
df = pd.concat([pd.read_csv(METRIC_HOME / f, index_col=0) for f in metrics_files])
df
# Out:
#               dataset    metric    tshpo                 name     sota  \
# 0         Bioresponse  accuracy  0.83048            Auto-CASH  0.81342
# 1         Bioresponse   roc_auc  0.89784            Auto-CASH  0.88716
# 2    PhishingWebsites  accuracy  0.97776            Auto-CASH  0.97414
# 3    PhishingWebsites   roc_auc  0.99696            Auto-CASH  0.99666
# 4      bank-marketing  accuracy  0.90702            Auto-CASH  0.90418
# ..                ...       ...      ...                  ...      ...
# 107          spambase   roc_auc  0.99164  AutoMHS-GPT(gpt-4o)  0.95548
# 108       tic-tac-toe  accuracy  1.00000  AutoMHS-GPT(gpt-4o)  0.65620
# 109       tic-tac-toe   roc_auc  1.00000  AutoMHS-GPT(gpt-4o)  0.72640
# 110              wilt  accuracy  0.99092  AutoMHS-GPT(gpt-4o)  0.94630
# 111              wilt   roc_auc  0.99690  AutoMHS-GPT(gpt-4o)  0.88506
#
#      improved
# 0     0.01706
# 1     0.01068
# 2     0.00362
# 3     0.00030
# 4     0.00284
# ..        ...
# ...

# %%
# Out:
#                                       mean                                    \
#                                       sota
# name                             Auto-CASH          AutoMHS-GPT(gpt-4-turbo)
# metric                            accuracy  roc_auc                 accuracy
# dataset
# Bioresponse                        0.81342  0.88716                  0.78092
# PhishingWebsites                   0.97414  0.99666                  0.86870
# bank-marketing                     0.90418  0.92088                  0.88304
# breast-w                           0.97426  0.98714                  0.97712
# churn                              0.95640  0.91302                  0.85920
# climate-model-simulation-crashes   0.92592  0.89030                  0.92960
# credit-approval                    0.88118  0.92322                  0.86088
# credit-g                           0.76200  0.79658                  0.70000
# ...
