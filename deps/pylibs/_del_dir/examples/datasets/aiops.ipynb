# %%
from pylibs.dataset.DatasetAIOPS2018 import DatasetAIOps2018,AIOpsKPIID

windows_size=512
di = DatasetAIOps2018(kpi_id=AIOpsKPIID.D1,
  windows_size=windows_size, is_include_anomaly_windows=True,
                       valid_rate=0.2)
train_x, train_y, valid_x, valid_y, test_x, test_y=di.get_sliding_windows_three_splits()
train_x.shape,train_y.shape,valid_x.shape, valid_y.shape,test_x.shape,test_y.shape
# Out:
# INFO - DB url: sqlite://///Users/sunwu/SW-Research/py-search-lib/pylibs/../../datasets/dataset.sqlite
# INFO - DB url: sqlite://///Users/sunwu/SW-Research/py-search-lib/pylibs/../../datasets/dataset.sqlite
# INFO - Received train_data_sample_rate=1.0, directly converted to float 1.0
# ((118895, 512), (118895,), (29724, 512), (29724,), (145744, 512), (145744,))

# %%
from pylibs.dataset.DatasetAIOPS2018 import DatasetAIOps2018,AIOpsKPIID

windows_size=128
di = DatasetAIOps2018(kpi_id=AIOpsKPIID.D1,
  windows_size=windows_size, is_include_anomaly_windows=True,
                       valid_rate=0.2)
train_x, train_y, valid_x, valid_y, test_x, test_y=di.get_sliding_windows_three_splits()
train_x.shape,train_y.shape,valid_x.shape, valid_y.shape,test_x.shape,test_y.shape
# Out:
# INFO - DB url: sqlite://///Users/sunwu/SW-Research/py-search-lib/pylibs/../../datasets/dataset.sqlite
# INFO - DB url: sqlite://///Users/sunwu/SW-Research/py-search-lib/pylibs/../../datasets/dataset.sqlite
# INFO - Received train_data_sample_rate=1.0, directly converted to float 1.0
# ((119202, 128), (119202,), (29801, 128), (29801,), (146128, 128), (146128,))

# %%
from pylibs.dataset.DatasetAIOPS2018 import DatasetAIOps2018,AIOpsKPIID

windows_size=128
di = DatasetAIOps2018(kpi_id=AIOpsKPIID.D1,
  windows_size=windows_size, is_include_anomaly_windows=True,
                      valid_rate=0.2,
  time_step=2)
train_x, train_y, valid_x, valid_y, test_x, test_y=di.get_sliding_windows_three_splits()
train_x.shape,train_y.shape,valid_x.shape, valid_y.shape,test_x.shape,test_y.shape
# Out:
# INFO - DB url: sqlite://///Users/sunwu/SW-Research/py-search-lib/pylibs/../../datasets/dataset.sqlite
# INFO - DB url: sqlite://///Users/sunwu/SW-Research/py-search-lib/pylibs/../../datasets/dataset.sqlite
# INFO - Received train_data_sample_rate=1.0, directly converted to float 1.0
# ((59601, 128), (59601,), (14901, 128), (14901,), (73064, 128), (73064,))

# %%
from matplotlib.figure import Figure
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

# 创建图
fig: Figure = plt.figure(figsize=(32, 8))

# 添加子图
# add_subplot(n_rows, n_cols, index)
ax1: Axes = fig.add_subplot(2, 1, 1)
ax1.plot(train_x[0])
